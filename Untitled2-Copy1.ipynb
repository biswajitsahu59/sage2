# %%
import pandas as pd
pd.read_parquet('s3://idq-analysis/output/part-00000-37024432-ef4e-489d-820f-e8d153d1c0ec-c000.snappy.parquet').head(100)
# Out:
#           ASIN    product_type snapshot_date ATTRIBUTE_NAME ATTRIBUTE_VALE
# 0   B0CVBM8ZY6  COSTUME_OUTFIT    2024-06-01   closure_type        Pull On
# 1   B0CVBM8ZY6  COSTUME_OUTFIT    2024-06-01     brand_name        Generic
# 2   B0CVBM8ZY6  COSTUME_OUTFIT    2024-06-01    finish_type           None
# 3   B0CVBM8ZY6  COSTUME_OUTFIT    2024-06-01     item_shape           None
# 4   B0CVBM8ZY6  COSTUME_OUTFIT    2024-06-01    league_name           None
# ..         ...             ...           ...            ...            ...
# 95  B0CW5XL1ZX     SAFETY_MASK    2024-06-01           None           None
# 96  B0CXMVKMQ8  COSTUME_OUTFIT    2024-06-01   closure_type         Zipper
# 97  B0CXMVKMQ8  COSTUME_OUTFIT    2024-06-01     brand_name  Cayon Fashion
# 98  B0CXMVKMQ8  COSTUME_OUTFIT    2024-06-01    finish_type           None
# 99  B0CXMVKMQ8  COSTUME_OUTFIT    2024-06-01     item_shape           None
#
# [100 rows x 5 columns]

# %%
import pandas as pd
pd.read_parquet('s3://cradle-dumps-2/2024-04-1/q_n_a.parquet')
#! aws s3 ls --human 's3://cradle-dumps-2/2024-04-1/'
# Out:
#               asin marketplace_id  \
# 0       B00L2B1YRY          44571
# 3       B00GNVVITM          44571
# 8       B00791FFYE          44571
# 9       B00GC441U8          44571
# 13      B004MWJRR4          44571
# ...            ...            ...
# 354113  8201057422          44571
# 354114  B0B2RZX6XG          44571
# 354115  B0B5R7VKPR          44571
# 354117  B0BCHXK4LV          44571
# 354119  B07FZ4ZSZH          44571
#
#                                             question_text
# 0              Is this laptop supporting VT-x technology?
# 3       Want to buy this product, but can you please c...
# 8       Nice powder continue this product forever i lo...
# 9       How much ROM allocated for applications.? what...
# 13      Does the earphone have a mic ? Is it compatibl...
# ...                                                   ...
# 354113                            Is l size is available?
# 354114                    What is Guarantee and warantee?
# ...
