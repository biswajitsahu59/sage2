# %%
import pandas as pd

# %%
pip install \
> sentence-transformers==2.7.0 \
> transformers==4.38.2 \
> huggingface_hub==0.23.0

# %%
# !nvidia-smi
# Out:
# Wed Mar  4 19:03:15 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.211.01             Driver Version: 570.211.01     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A10G                    On  |   00000000:00:1E.0 Off |                    0 |
# |  0%   23C    P8             15W /  300W |       0MiB /  23028MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
conda install pytorch torchvision torchaudio pytorch-cuda=12.1 -c pytorch -c nvidia -y
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.11.0
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda=12.1
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libavif16-1.4.0            |       hcfa2d63_0         145 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         145 KB
#
# The following NEW packages will be INSTALLED:
#
#   aom                conda-forge/linux-64::aom-3.9.1-hac33072_0
# ...

# %%
conda install -c conda-forge transformers=4.41 -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.11.0
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#   added / updated specs:
#     - transformers=4.41
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tokenizers-0.19.1          |  py312hfef1a59_0         2.6 MB  conda-forge
#     transformers-4.41.2        |     pyhd8ed1ab_0         3.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.8 MB
#
# The following packages will be UPDATED:
#
# ...

# %%
conda install -c conda-forge pyarrow=14.0.2 -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.11.0
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#   added / updated specs:
#     - pyarrow=14.0.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aws-c-auth-0.8.0           |       hcd8ed7f_7         105 KB  conda-forge
#     aws-c-cal-0.8.0            |       he70792b_1          47 KB  conda-forge
#     aws-c-common-0.10.0        |       hb9d3cd8_0         230 KB  conda-forge
#     aws-c-compression-0.3.0    |       hba2fe39_1          19 KB  conda-forge
#     aws-c-event-stream-0.5.0   |       h127f702_4          53 KB  conda-forge
# ...

# %%
pip uninstall sentence-transformers -y
# Out:
# Found existing installation: sentence-transformers 5.2.3
# Uninstalling sentence-transformers-5.2.3:
#   Successfully uninstalled sentence-transformers-5.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sentence-transformers==2.2.2
# Out:
# ERROR: Invalid requirement: 'sentence-transformers==2.2.2-y': Expected end or semicolon (after version specifier)
#     sentence-transformers==2.2.2-y
#                          ~~~~~~~^
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c pytorch faiss-cpu -y

# %%
! conda install pytorch torchvision torchaudio pytorch-cuda=12.1 -c pytorch -c nvidia -y
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.11.0
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.

# %%
! conda install -c conda-forge sentence-transformers transformers datasets accelerate huggingface_hub -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.11.0
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#   added / updated specs:
#     - accelerate
#     - datasets
#     - huggingface_hub
#     - sentence-transformers
#     - transformers
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     accelerate-1.13.0          |     pyhcf101f3_0         268 KB  conda-forge
#     safetensors-0.7.0          |  py312h0ccc70a_0         440 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         708 KB
#
# ...

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 import torch
#       3 print("CUDA available:", torch.cuda.is_available())
# ----> 4 print("GPU:", torch.cuda.get_device_name(0))
#
# File ~/anaconda3/envs/python3/lib/python3.12/site-packages/torch/cuda/__init__.py:493, in get_device_name(device)
#     481 def get_device_name(device: Optional[_device_t] = None) -> str:
#     482     r"""Get the name of a device.
#     483
#     484     Args:
#    (...)    491         str: the name of the device
#     492     """
# --> 493     return get_device_properties(device).name
#
# File ~/anaconda3/envs/python3/lib/python3.12/site-packages/torch/cuda/__init__.py:523, in get_device_properties(device)
#     513 def get_device_properties(device: _device_t) -> _CudaDeviceProperties:
#     514     r"""Get the properties of a device.
#     515
# ...

# %%
import torch
import faiss
from sentence_transformers import SentenceTransformer

print("Torch CUDA available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0))
print("FAISS version:", faiss.__version__)

model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Torch CUDA available: False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 6
#       3 from sentence_transformers import SentenceTransformer
#       5 print("Torch CUDA available:", torch.cuda.is_available())
# ----> 6 print("GPU Name:", torch.cuda.get_device_name(0))
#       7 print("FAISS version:", faiss.__version__)
#       9 model = SentenceTransformer("all-MiniLM-L6-v2")
#
# File ~/anaconda3/envs/python3/lib/python3.12/site-packages/torch/cuda/__init__.py:493, in get_device_name(device)
#     481 def get_device_name(device: Optional[_device_t] = None) -> str:
#     482     r"""Get the name of a device.
#     483
#     484     Args:
#    (...)    491         str: the name of the device
#     492     """
# --> 493     return get_device_properties(device).name
#
# ...
