# %%
import pandas as pd

ab=pd.read_csv('s3://idq-analysis/fill_rate/output/part-00000-3e7cd0fa-336f-4f20-aa85-4e32bcfc49f1-c000.csv')

# %%
ab
# Out:
#                ASIN        ptd  \
# 0        B0F8422BYJ   PINBOARD
# 1        B0DKDFWXD1   PINBOARD
# 2        B0DKDHH4F8   PINBOARD
# 3        B0DKDHL43G   PINBOARD
# 4        B0DKDHQZ92   PINBOARD
# ...             ...        ...
# 1756449  B0BQZZSXC2  SPORT_BAT
# 1756450  B0BRFSV15Y  SPORT_BAT
# 1756451  B07XL28R9R  SPORT_BAT
# 1756452  B0DWV81NHN  SPORT_BAT
# 1756453  B0DXBX5F9X  SPORT_BAT
#
#                                       warranty_description
# 0                                                      NaN
# 1        This product is covered under the ArtzFolio Pr...
# 2        This product is covered under the ArtzFolio Pr...
# 3        This product is covered under the ArtzFolio Pr...
# 4        This product is covered under the ArtzFolio Pr...
# ...                                                    ...
# 1756449                                        No Warranty
# 1756450                                        No Warranty
# ...
